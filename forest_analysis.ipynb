# %%
import pandas as pd
import os

import kagglehub

# Download latest version
data_path = kagglehub.dataset_download("kanchana1990/global-forest-insights-1990-2020-fao")
files = os.listdir(data_path)

print("Path to dataset files:", data_path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.10), please consider upgrading to the latest version (1.0.0).
# Path to dataset files: /Users/aleynayildiz/.cache/kagglehub/datasets/kanchana1990/global-forest-insights-1990-2020-fao/versions/1

# %%
os.listdir(data_path)
csv_file = [f for f in files if f.endswith('.csv')][0]
full_path = os.path.join(data_path, csv_file)

df = pd.read_csv(full_path)

print('Data has been succsessfully uploded')
df.head()
# Out:
# Data has been succsessfully uploded
#    CountryID Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 0        NaN            WORLD         4236433.42         4158049.52
# 1        4.0      Afghanistan            1208.44            1208.44
# 2        8.0          Albania             788.80             769.30
# 3       12.0          Algeria            1667.00            1579.00
# 4       16.0   American Samoa              18.07              17.73
#
#    Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 0         4106316.94
#          4058930.81
# 1            1208.44           1208.44            1208.44
# 2             782.07            789.19             788.90
# 3            1918.00              1956            1949.00
# 4              17.43             17.28              17.13
#
#    Total Land Area, 2020  \
# 0             13003000.0
# 1                65286.0
# 2                 2740.0
# 3               238174.0
# 4                   20.0
#
#    Forest Area as a Proportion of Total Land Area, 2020  \
# 0                                              31.13
# 1                                               1.85
# 2                                              28.79
# 3                                               0.82
# 4                                              85.65
#
#   Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015
# 0                    10200                                    98040
# 1                      ...                                      ...
# 2                      ...                                      ...
# 3                      5.4                                      ...
# 4                      ...                                        0
